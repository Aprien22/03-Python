# %%
import numpy as np

A = np.array([[1, 2], [3, 4]])
B = np.array([[5, 6], [7, 8]])

print(A)
print(B)

print(f"A * B = {np.dot(A, B)}")
# Out:
# [[1 2]
#  [3 4]]
# [[5 6]
#  [7 8]]
# A * B = [[19 22]
#  [43 50]]
